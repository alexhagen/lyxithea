# %%
import lyxithea.lyxithea as lyx
import lyxithea.puslides as lyxs
from pyg import twod as pyg2d

lyx.exporting(False)

pyg2d.context("thesis")
bib = lyx.bib('bibs/dissertation.bib')
slides = lyxs.puslides(bib)
slides.chapter_paths(['~/data/dissertation'])
slides.title('Detection and Interdiction of Shielded and Unshielded Special ' + 
             'Nuclear Material using Tensioned Metastable Fluid Detectors')
slides.author('Alex Hagen')
slides.subtitle('Preliminary Doctoral Defense')
slides.affiliation('Purdue University')
slides.venue('Metastable Fluids and Advanced Research Laboratory')
slides.city('Lafayette, IN')
# Out:
# <span>$\newcommand{\unit}[1]{\mathrm{\; #1}}$</span>
# <span>$\newcommand{\ce}[1]{\mathrm{#1}}$</span>
# <link rel="stylesheet" href="https://cdn.rawgit.com/tiaanduplessis/wenk/master/dist/wenk.css">
# <style> span.abbr{ color: #999; } </style>
# <style> [data-wenk]:after { z-index: 1000000000; } </style>

# %%
slides.part('Introduction')
slides.chapter('Motivation')
# Out:
# \part{Introduction}
# \def\nameofchapter{Motivation}

# %%
slides.chapterslidetitle('Threshold Energy Neutron Analysis using TMFDs')
slides.chapterslidesubtitle(r'''
Archambault, B., Hagen, A., Masuda, K., Yamakawa, N., & Taleyarkhan, R. P. (2016). **Threshold Rejection Mode Active Interrogation of SNMs Using Continuous Beam DD Neutrons with Centrifugal and Acoustic Tensioned Metastable Fluid Detectors.** IEEE Transactions on Nuclear Science, 1–1. https://doi.org/10.1109/TNS.2016.2628244''')
# Out:
#               <div style='width:80%; border: solid 1px black;'>
#                 <img src='data:image/svg+xml;charset=UTF-8,<?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="648pt" height="504pt" viewBox="0 0 648 504" version="1.1">
# <defs>
# <g>
# <symbol overflow="visible" id="glyph0-0">
# <path style="stroke:none;" d=""/>
# </symbol>
# <symbol overflow="visible" id="glyph0-1">
# <path style="stroke:none;" d="M 12.671875 -40.53125 L 17.28125 -40.53125 L 17.28125 -47.828125 L 0.421875 -47.828125 L 0.421875 -40.53125 L 5.328125 -40.53125 L 5.328125 0 L 12.671875 0 Z M 12.671875 -40.53125 "/>
# </symbol>
# <symbol overflow="visible" id="glyph0-2">
# ...
